# %%
# 🔹 Подключаем Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 🔹 Папка для проектов на Google Drive
# %cd /content/drive/MyDrive/Colab\ Notebooks/Kaggle_Project/Kaggle_cars

# 🔹 Настройка Git
# !git config --global user.name "MaximPodd"
# !git config --global user.email "maximpodd@gmail.com"

# !mkdir -p ~/.ssh
# !cp /content/drive/MyDrive/Colab\ Notebooks/ssh/id_ed25519* ~/.ssh/
# !chmod 600 ~/.ssh/id_ed25519
# !chmod 644 ~/.ssh/id_ed25519.pub

# Добавляем GitHub в known_hosts
# !ssh-keyscan github.com >> ~/.ssh/known_hosts
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Kaggle_Project/Kaggle_cars
# # github.com:22 SSH-2.0-88f9acd9
# # github.com:22 SSH-2.0-88f9acd9
# # github.com:22 SSH-2.0-88f9acd9
# # github.com:22 SSH-2.0-88f9acd9
# # github.com:22 SSH-2.0-88f9acd9

# %%
# Проверяем соединение:
# !ssh -T git@github.com
# Out:
# Hi MaximPodd! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kaggle_Project/Kaggle_cars

# %% [markdown]
# #### Фиксируем seed'ы

# %%
import os
import random
import numpy as np

import torch
import tensorflow as tf

def set_all_seeds(seed):

    # python's seeds
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

    # torch's seeds
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # tensorflow's seed
    tf.random.set_seed(seed)

DEFAULT_RANDOM_SEED = 2021
set_all_seeds(seed=DEFAULT_RANDOM_SEED)
